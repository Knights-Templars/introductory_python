# %% [markdown]
# ### What is pandas?
# #### Pandas is a Python library used for working with data sets.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Datastructure
# 1. Series -- one dimensional
# 2. DataFrame -- two dimensional

# %%
# Creating a series from a list
data = [1, 2, 3, 4, 5]
s = pd.Series(data)

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Creating a series from a list with custom index
data = [1, 2, 3, 4, 5]
index = ['A', 'B', 'C', 'D', 'E']

s_with_index = pd.Series(data, index=index)

# %%
s_with_index
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
# Create a dataframe from lists
data_wc_football = {
    'Country': ['Spain', 'Germany', 'France', 'Argentina'],
    'Year': ['2010', '2014', '2018', '2022'],
    'Player': ['Iniesta', 'Klose', 'Mbappe', 'Messi']
}

df_wc_football = pd.DataFrame(data_wc_football)

# %%
df_wc_football
# Out:
#      Country  Year   Player
# 0      Spain  2010  Iniesta
# 1    Germany  2014    Klose
# 2     France  2018   Mbappe
# 3  Argentina  2022    Messi

# %%
# Create a dataframe from lists with custom index
data_wc_football = {
    'Country': ['Spain', 'Germany', 'France', 'Argentina'],
    'Year': ['2010', '2014', '2018', '2022'],
    'Player': ['Iniesta', 'Klose', 'Mbappe', 'Messi']
}

index = ['A', 'B', 'C', 'D']

df_wc_football_with_index = pd.DataFrame(data_wc_football, index=index)

# %%
df_wc_football_with_index
# Out:
#      Country  Year   Player
# A      Spain  2010  Iniesta
# B    Germany  2014    Klose
# C     France  2018   Mbappe
# D  Argentina  2022    Messi

# %% [markdown]
# ### What is a dictionary?
# #### A dictionary is a collection of key-value pairs. Each key is associated with a value.

# %%
# Create a dictionary using a dict constrictor
data_wc_football = {
    'Country': ['Spain', 'Germany', 'France', 'Argentina'],
    'Year': ['2010', '2014', '2018', '2022'],
    'Player': ['Iniesta', 'Klose', 'Mbappe', 'Messi']
}

# %%
# Create a dataframe from a dictionary

data_wc_football = {
    'Country': ['Spain', 'Germany', 'France', 'Argentina'],
    'Year': ['2010', '2014', '2018', '2022'],
    'Player': ['Iniesta', 'Klose', 'Mbappe', 'Messi']
}

df_from_dict = pd.DataFrame(data_wc_football)

# %%
df_from_dict
# Out:
#      Country  Year   Player
# 0      Spain  2010  Iniesta
# 1    Germany  2014    Klose
# 2     France  2018   Mbappe
# 3  Argentina  2022    Messi

# %%
df_wc_football_with_index.dtypes
# Out:
# Country    object
# Year       object
# Player     object
# dtype: object

# %%
# Create a fake dataframe with random data

# shape of the dataframe
num_rows = 100
num_cols = 20

data = np.random.randn(num_rows, num_cols) # create a 2D array of random numbers from a normal distribution
# rename the columns

columns = ['column_' + str(i) for i in range(num_cols)]
index = ['row_' + str(i) for i in range(num_rows)]

df = pd.DataFrame(data, columns=columns, index=index)

# %%
df
# Out:
#         column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# row_0  -0.061867  3.494840  1.366145 -0.282716  1.232646 -0.572733 -0.326738
# row_1  -1.314013  1.432290  1.152912  1.156307  1.297124  0.693444  0.812662
# row_2  -1.452162  1.109068  1.246356  0.716861 -0.803672  1.130528 -0.961859
# row_3   0.767121 -1.410148  0.029519  0.472326  0.020758 -0.489636 -0.527717
# row_4   0.962889  0.765808 -1.365236  1.370107  0.980378  0.609408 -1.289655
# ...          ...       ...       ...       ...       ...       ...       ...
# row_95  1.439471  1.750278  0.884833 -0.679433 -1.032590  1.247483  2.134904
# row_96  1.311461 -0.134759  0.853030  2.352509  2.903976  0.188207  0.390707
# row_97  0.714377  0.043508  3.199866  0.713160 -0.326792 -0.058511 -0.039244
# row_98  0.552253 -0.335895  1.070005  0.103915  0.588325  0.959030  0.253804
# row_99  0.162243  0.091577  1.497532  1.247754  0.409762  0.579131  0.241205
#
#         column_7  column_8  column_9  column_10  column_11  column_12  \
# row_0  -1.213385  0.723445  1.127667   0.994296  -0.313927  -2.422527
# row_1   2.682947 -0.296179 -0.161810  -0.691866  -0.489068  -0.186374
# row_2   1.785122 -0.573043 -0.477888  -0.619135   0.415023  -0.455231
# row_3   0.179453  1.982950  0.561855   1.635451  -0.541245  -0.854839
# row_4   0.730033  0.089912  0.930447   0.226197   1.594845  -0.319074
# ...          ...       ...       ...        ...        ...        ...
# row_95  0.782725 -1.464817 -0.839772  -2.079428  -0.653747   1.867005
# row_96 -1.117908 -0.018376  0.763738  -2.141927   0.552507   0.530554
# row_97  2.191589 -0.442348  0.510670   1.083935  -1.141513  -0.785940
# row_98 -0.371038  0.952739  0.032104   0.908743  -1.888959   0.237859
# row_99  1.588943 -0.166546  1.341730   1.219289   0.438084   1.308941
#
#         column_13  column_14  column_15  column_16  column_17  column_18  \
# row_0   -1.287514  -1.023617  -1.936117   0.284309  -0.275824  -0.292722
# row_1   -0.581903   0.417727  -0.029335  -1.112440  -1.010581  -0.662007
# row_2   -1.205265   0.115913   2.056874  -0.193720  -0.569588  -0.077930
# row_3   -0.490948  -1.151506   0.910729  -1.401155  -0.326643   1.164274
# row_4   -1.216257  -1.086353  -0.149670  -0.791340  -1.361137   0.500909
# ...           ...        ...        ...        ...        ...        ...
# row_95   0.632023  -2.197502  -1.450950  -1.865643   1.342990  -0.685883
# row_96  -0.630892   0.700762  -1.998996   1.221675   0.088607  -0.559924
# row_97   1.157206  -1.140128   0.557896   0.963973  -0.548824   0.271483
# row_98   0.703237  -0.552694   1.735655   0.078898  -1.314820  -2.646178
# row_99  -1.505208  -0.550281  -0.568920   1.517479  -2.393930  -0.780642
#
#         column_19
# row_0   -0.291986
# row_1    0.908214
# row_2    1.158553
# row_3   -0.193142
# row_4   -1.058117
# ...           ...
# row_95   0.611289
# row_96  -1.436727
# row_97   0.462247
# row_98   0.524606
# row_99  -0.747883
#
# [100 rows x 20 columns]

# %%
# check the indices
df.index
# Out:
# Index(['row_0', 'row_1', 'row_2', 'row_3', 'row_4', 'row_5', 'row_6', 'row_7',
#        'row_8', 'row_9', 'row_10', 'row_11', 'row_12', 'row_13', 'row_14',
#        'row_15', 'row_16', 'row_17', 'row_18', 'row_19', 'row_20', 'row_21',
#        'row_22', 'row_23', 'row_24', 'row_25', 'row_26', 'row_27', 'row_28',
#        'row_29', 'row_30', 'row_31', 'row_32', 'row_33', 'row_34', 'row_35',
#        'row_36', 'row_37', 'row_38', 'row_39', 'row_40', 'row_41', 'row_42',
#        'row_43', 'row_44', 'row_45', 'row_46', 'row_47', 'row_48', 'row_49',
#        'row_50', 'row_51', 'row_52', 'row_53', 'row_54', 'row_55', 'row_56',
#        'row_57', 'row_58', 'row_59', 'row_60', 'row_61', 'row_62', 'row_63',
#        'row_64', 'row_65', 'row_66', 'row_67', 'row_68', 'row_69', 'row_70',
#        'row_71', 'row_72', 'row_73', 'row_74', 'row_75', 'row_76', 'row_77',
#        'row_78', 'row_79', 'row_80', 'row_81', 'row_82', 'row_83', 'row_84',
#        'row_85', 'row_86', 'row_87', 'row_88', 'row_89', 'row_90', 'row_91',
#        'row_92', 'row_93', 'row_94', 'row_95', 'row_96', 'row_97', 'row_98',
#        'row_99'],
#       dtype='object')

# %%
# check the columns
df.columns
# Out:
# Index(['column_0', 'column_1', 'column_2', 'column_3', 'column_4', 'column_5',
#        'column_6', 'column_7', 'column_8', 'column_9', 'column_10',
#        'column_11', 'column_12', 'column_13', 'column_14', 'column_15',
#        'column_16', 'column_17', 'column_18', 'column_19'],
#       dtype='object')

# %%
# sum the values of the dataframe row wise (horizontally)
# Adding a new column

df['sum'] = df.sum(axis=1)

# %%
df
# Out:
#         column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# row_0  -0.061867  3.494840  1.366145 -0.282716  1.232646 -0.572733 -0.326738
# row_1  -1.314013  1.432290  1.152912  1.156307  1.297124  0.693444  0.812662
# row_2  -1.452162  1.109068  1.246356  0.716861 -0.803672  1.130528 -0.961859
# row_3   0.767121 -1.410148  0.029519  0.472326  0.020758 -0.489636 -0.527717
# row_4   0.962889  0.765808 -1.365236  1.370107  0.980378  0.609408 -1.289655
# ...          ...       ...       ...       ...       ...       ...       ...
# row_95  1.439471  1.750278  0.884833 -0.679433 -1.032590  1.247483  2.134904
# row_96  1.311461 -0.134759  0.853030  2.352509  2.903976  0.188207  0.390707
# row_97  0.714377  0.043508  3.199866  0.713160 -0.326792 -0.058511 -0.039244
# row_98  0.552253 -0.335895  1.070005  0.103915  0.588325  0.959030  0.253804
# row_99  0.162243  0.091577  1.497532  1.247754  0.409762  0.579131  0.241205
#
#         column_7  column_8  column_9  ...  column_11  column_12  column_13  \
# row_0  -1.213385  0.723445  1.127667  ...  -0.313927  -2.422527  -1.287514
# row_1   2.682947 -0.296179 -0.161810  ...  -0.489068  -0.186374  -0.581903
# row_2   1.785122 -0.573043 -0.477888  ...   0.415023  -0.455231  -1.205265
# row_3   0.179453  1.982950  0.561855  ...  -0.541245  -0.854839  -0.490948
# row_4   0.730033  0.089912  0.930447  ...   1.594845  -0.319074  -1.216257
# ...          ...       ...       ...  ...        ...        ...        ...
# row_95  0.782725 -1.464817 -0.839772  ...  -0.653747   1.867005   0.632023
# row_96 -1.117908 -0.018376  0.763738  ...   0.552507   0.530554  -0.630892
# row_97  2.191589 -0.442348  0.510670  ...  -1.141513  -0.785940   1.157206
# row_98 -0.371038  0.952739  0.032104  ...  -1.888959   0.237859   0.703237
# row_99  1.588943 -0.166546  1.341730  ...   0.438084   1.308941  -1.505208
#
#         column_14  column_15  column_16  column_17  column_18  column_19  \
# row_0   -1.023617  -1.936117   0.284309  -0.275824  -0.292722  -0.291986
# row_1    0.417727  -0.029335  -1.112440  -1.010581  -0.662007   0.908214
# row_2    0.115913   2.056874  -0.193720  -0.569588  -0.077930   1.158553
# row_3   -1.151506   0.910729  -1.401155  -0.326643   1.164274  -0.193142
# row_4   -1.086353  -0.149670  -0.791340  -1.361137   0.500909  -1.058117
# ...           ...        ...        ...        ...        ...        ...
# row_95  -2.197502  -1.450950  -1.865643   1.342990  -0.685883   0.611289
# row_96   0.700762  -1.998996   1.221675   0.088607  -0.559924  -1.436727
# row_97  -1.140128   0.557896   0.963973  -0.548824   0.271483   0.462247
# row_98  -0.552694   1.735655   0.078898  -1.314820  -2.646178   0.524606
# row_99  -0.550281  -0.568920   1.517479  -2.393930  -0.780642  -0.747883
#
#              sum
# row_0  -1.078327
# row_1   4.018051
# row_2   2.344805
# row_3   0.337456
# row_4   0.124094
# ...          ...
# row_95 -0.256764
# row_96  3.818223
# row_97  7.386610
# row_98  1.591589
# row_99  4.930258
#
# [100 rows x 21 columns]

# %%
# Selecting a column

df['column_1']
# Out:
# row_0     3.494840
# row_1     1.432290
# row_2     1.109068
# row_3    -1.410148
# row_4     0.765808
#             ...
# row_95    1.750278
# row_96   -0.134759
# row_97    0.043508
# row_98   -0.335895
# row_99    0.091577
# Name: column_1, Length: 100, dtype: float64

# %%
type(df['column_1'])
# Out:
# pandas.core.series.Series

# %%
# Slicing the dataframe by rows

df[0:5]
# Out:
#        column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# row_0 -0.061867  3.494840  1.366145 -0.282716  1.232646 -0.572733 -0.326738
# row_1 -1.314013  1.432290  1.152912  1.156307  1.297124  0.693444  0.812662
# row_2 -1.452162  1.109068  1.246356  0.716861 -0.803672  1.130528 -0.961859
# row_3  0.767121 -1.410148  0.029519  0.472326  0.020758 -0.489636 -0.527717
# row_4  0.962889  0.765808 -1.365236  1.370107  0.980378  0.609408 -1.289655
#
#        column_7  column_8  column_9  ...  column_11  column_12  column_13  \
# row_0 -1.213385  0.723445  1.127667  ...  -0.313927  -2.422527  -1.287514
# row_1  2.682947 -0.296179 -0.161810  ...  -0.489068  -0.186374  -0.581903
# row_2  1.785122 -0.573043 -0.477888  ...   0.415023  -0.455231  -1.205265
# row_3  0.179453  1.982950  0.561855  ...  -0.541245  -0.854839  -0.490948
# row_4  0.730033  0.089912  0.930447  ...   1.594845  -0.319074  -1.216257
#
#        column_14  column_15  column_16  column_17  column_18  column_19  \
# row_0  -1.023617  -1.936117   0.284309  -0.275824  -0.292722  -0.291986
# row_1   0.417727  -0.029335  -1.112440  -1.010581  -0.662007   0.908214
# row_2   0.115913   2.056874  -0.193720  -0.569588  -0.077930   1.158553
# row_3  -1.151506   0.910729  -1.401155  -0.326643   1.164274  -0.193142
# row_4  -1.086353  -0.149670  -0.791340  -1.361137   0.500909  -1.058117
#
#             sum
# row_0 -1.078327
# row_1  4.018051
# row_2  2.344805
# row_3  0.337456
# row_4  0.124094
#
# [5 rows x 21 columns]

# %%
# slicing the dataframe by columns

df[['column_1', 'column_2']]
# Out:
#         column_1  column_2
# row_0   3.494840  1.366145
# row_1   1.432290  1.152912
# row_2   1.109068  1.246356
# row_3  -1.410148  0.029519
# row_4   0.765808 -1.365236
# ...          ...       ...
# row_95  1.750278  0.884833
# row_96 -0.134759  0.853030
# row_97  0.043508  3.199866
# row_98 -0.335895  1.070005
# row_99  0.091577  1.497532
#
# [100 rows x 2 columns]

# %%
# slicing the dataframe by rows and columns

# See we are using a different method here - loc

df.loc[:, ['column_1', 'column_2']]
# Out:
#         column_1  column_2
# row_0   3.494840  1.366145
# row_1   1.432290  1.152912
# row_2   1.109068  1.246356
# row_3  -1.410148  0.029519
# row_4   0.765808 -1.365236
# ...          ...       ...
# row_95  1.750278  0.884833
# row_96 -0.134759  0.853030
# row_97  0.043508  3.199866
# row_98 -0.335895  1.070005
# row_99  0.091577  1.497532
#
# [100 rows x 2 columns]

# %%
# slicing the dataframe by rows and columns

# df.loc - access the rows and columns by labels
df.loc['row_1': 'row_5', ['column_1', 'column_2']]
# Out:
#        column_1  column_2
# row_1  1.432290  1.152912
# row_2  1.109068  1.246356
# row_3 -1.410148  0.029519
# row_4  0.765808 -1.365236
# row_5 -1.311193  2.057363

# %%
x = "hello_world"

y = ''
for i in range(5):
    y += x[i]

# %%
x[13:15]
# Out:
# ''

# %%
y = x[0:5]

# %%
y
# Out:
# 'hello'

# %%
x[0:-2]
# Out:
# 'hello_wor'

# %%
x = np.random.uniform(size=(100, 100))

# %%
x[3:400]
# Out:
# array([[0.28472373, 0.75735875, 0.66627589, ..., 0.24338735, 0.61829506,
#         0.15459168],
#        [0.45907549, 0.07770266, 0.45803428, ..., 0.05095434, 0.41293472,
#         0.77508856],
#        [0.38054147, 0.6663018 , 0.76533986, ..., 0.00942927, 0.32254622,
#         0.96326822],
#        ...,
#        [0.05519384, 0.55952701, 0.46437679, ..., 0.20861257, 0.58710721,
#         0.16033858],
#        [0.12145443, 0.94113895, 0.97535452, ..., 0.62322387, 0.02000413,
#         0.76724308],
#        [0.43025822, 0.26604501, 0.86128776, ..., 0.92820487, 0.30284401,
#         0.51298912]])

# %%
# slicing the dataframe by rows and columns using iloc

# df.iloc - access the rows and columns by integer index
# remmeber 1: 6 means rows_1 to rows_5

df.iloc[1:6, 1:3]
# Out:
#        column_1  column_2
# row_1  1.432290  1.152912
# row_2  1.109068  1.246356
# row_3 -1.410148  0.029519
# row_4  0.765808 -1.365236
# row_5 -1.311193  2.057363

# %% [markdown]
# #### df.loc -- label based indexing (labels / boolean)
# #### df.iloc -- interger based indexing

# %%
# find the positive values in the dataframe (conditional selection)

postive_df = df[df > 0]

# %%
df>0
# Out:
#         column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# row_0      False      True      True     False      True     False     False
# row_1      False      True      True      True      True      True      True
# row_2      False      True      True      True     False      True     False
# row_3       True     False      True      True      True     False     False
# row_4       True      True     False      True      True      True     False
# ...          ...       ...       ...       ...       ...       ...       ...
# row_95      True      True      True     False     False      True      True
# row_96      True     False      True      True      True      True      True
# row_97      True      True      True      True     False     False     False
# row_98      True     False      True      True      True      True      True
# row_99      True      True      True      True      True      True      True
#
#         column_7  column_8  column_9  ...  column_11  column_12  column_13  \
# row_0      False      True      True  ...      False      False      False
# row_1       True     False     False  ...      False      False      False
# row_2       True     False     False  ...       True      False      False
# row_3       True      True      True  ...      False      False      False
# row_4       True      True      True  ...       True      False      False
# ...          ...       ...       ...  ...        ...        ...        ...
# row_95      True     False     False  ...      False       True       True
# row_96     False     False      True  ...       True       True      False
# row_97      True     False      True  ...      False      False       True
# row_98     False      True      True  ...      False       True       True
# row_99      True     False      True  ...       True       True      False
#
#         column_14  column_15  column_16  column_17  column_18  column_19  \
# row_0       False      False       True      False      False      False
# row_1        True      False      False      False      False       True
# row_2        True       True      False      False      False       True
# row_3       False       True      False      False       True      False
# row_4       False      False      False      False       True      False
# ...           ...        ...        ...        ...        ...        ...
# row_95      False      False      False       True      False       True
# row_96       True      False       True       True      False      False
# row_97      False       True       True      False       True       True
# row_98      False       True       True      False      False       True
# row_99      False      False       True      False      False      False
#
#           sum
# row_0   False
# row_1    True
# row_2    True
# row_3    True
# row_4    True
# ...       ...
# row_95  False
# row_96   True
# row_97   True
# row_98   True
# row_99   True
#
# [100 rows x 21 columns]

# %%
postive_df
# Out:
#         column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# row_0        NaN  3.494840  1.366145       NaN  1.232646       NaN       NaN
# row_1        NaN  1.432290  1.152912  1.156307  1.297124  0.693444  0.812662
# row_2        NaN  1.109068  1.246356  0.716861       NaN  1.130528       NaN
# row_3   0.767121       NaN  0.029519  0.472326  0.020758       NaN       NaN
# row_4   0.962889  0.765808       NaN  1.370107  0.980378  0.609408       NaN
# ...          ...       ...       ...       ...       ...       ...       ...
# row_95  1.439471  1.750278  0.884833       NaN       NaN  1.247483  2.134904
# row_96  1.311461       NaN  0.853030  2.352509  2.903976  0.188207  0.390707
# row_97  0.714377  0.043508  3.199866  0.713160       NaN       NaN       NaN
# row_98  0.552253       NaN  1.070005  0.103915  0.588325  0.959030  0.253804
# row_99  0.162243  0.091577  1.497532  1.247754  0.409762  0.579131  0.241205
#
#         column_7  column_8  column_9  ...  column_11  column_12  column_13  \
# row_0        NaN  0.723445  1.127667  ...        NaN        NaN        NaN
# row_1   2.682947       NaN       NaN  ...        NaN        NaN        NaN
# row_2   1.785122       NaN       NaN  ...   0.415023        NaN        NaN
# row_3   0.179453  1.982950  0.561855  ...        NaN        NaN        NaN
# row_4   0.730033  0.089912  0.930447  ...   1.594845        NaN        NaN
# ...          ...       ...       ...  ...        ...        ...        ...
# row_95  0.782725       NaN       NaN  ...        NaN   1.867005   0.632023
# row_96       NaN       NaN  0.763738  ...   0.552507   0.530554        NaN
# row_97  2.191589       NaN  0.510670  ...        NaN        NaN   1.157206
# row_98       NaN  0.952739  0.032104  ...        NaN   0.237859   0.703237
# row_99  1.588943       NaN  1.341730  ...   0.438084   1.308941        NaN
#
#         column_14  column_15  column_16  column_17  column_18  column_19  \
# row_0         NaN        NaN   0.284309        NaN        NaN        NaN
# row_1    0.417727        NaN        NaN        NaN        NaN   0.908214
# row_2    0.115913   2.056874        NaN        NaN        NaN   1.158553
# row_3         NaN   0.910729        NaN        NaN   1.164274        NaN
# row_4         NaN        NaN        NaN        NaN   0.500909        NaN
# ...           ...        ...        ...        ...        ...        ...
# row_95        NaN        NaN        NaN   1.342990        NaN   0.611289
# row_96   0.700762        NaN   1.221675   0.088607        NaN        NaN
# row_97        NaN   0.557896   0.963973        NaN   0.271483   0.462247
# row_98        NaN   1.735655   0.078898        NaN        NaN   0.524606
# row_99        NaN        NaN   1.517479        NaN        NaN        NaN
#
#              sum
# row_0        NaN
# row_1   4.018051
# row_2   2.344805
# row_3   0.337456
# row_4   0.124094
# ...          ...
# row_95       NaN
# row_96  3.818223
# row_97  7.386610
# row_98  1.591589
# row_99  4.930258
#
# [100 rows x 21 columns]

# %%
postive_df = postive_df.fillna(99.99)

# %%
postive_df
# Out:
#          column_0   column_1   column_2   column_3   column_4   column_5  \
# row_0   99.990000   3.494840   1.366145  99.990000   1.232646  99.990000
# row_1   99.990000   1.432290   1.152912   1.156307   1.297124   0.693444
# row_2   99.990000   1.109068   1.246356   0.716861  99.990000   1.130528
# row_3    0.767121  99.990000   0.029519   0.472326   0.020758  99.990000
# row_4    0.962889   0.765808  99.990000   1.370107   0.980378   0.609408
# ...           ...        ...        ...        ...        ...        ...
# row_95   1.439471   1.750278   0.884833  99.990000  99.990000   1.247483
# row_96   1.311461  99.990000   0.853030   2.352509   2.903976   0.188207
# row_97   0.714377   0.043508   3.199866   0.713160  99.990000  99.990000
# row_98   0.552253  99.990000   1.070005   0.103915   0.588325   0.959030
# row_99   0.162243   0.091577   1.497532   1.247754   0.409762   0.579131
#
#          column_6   column_7   column_8   column_9  ...  column_11  column_12  \
# row_0   99.990000  99.990000   0.723445   1.127667  ...  99.990000  99.990000
# row_1    0.812662   2.682947  99.990000  99.990000  ...  99.990000  99.990000
# row_2   99.990000   1.785122  99.990000  99.990000  ...   0.415023  99.990000
# row_3   99.990000   0.179453   1.982950   0.561855  ...  99.990000  99.990000
# row_4   99.990000   0.730033   0.089912   0.930447  ...   1.594845  99.990000
# ...           ...        ...        ...        ...  ...        ...        ...
# row_95   2.134904   0.782725  99.990000  99.990000  ...  99.990000   1.867005
# row_96   0.390707  99.990000  99.990000   0.763738  ...   0.552507   0.530554
# row_97  99.990000   2.191589  99.990000   0.510670  ...  99.990000  99.990000
# row_98   0.253804  99.990000   0.952739   0.032104  ...  99.990000   0.237859
# row_99   0.241205   1.588943  99.990000   1.341730  ...   0.438084   1.308941
#
#         column_13  column_14  column_15  column_16  column_17  column_18  \
# row_0   99.990000  99.990000  99.990000   0.284309  99.990000  99.990000
# row_1   99.990000   0.417727  99.990000  99.990000  99.990000  99.990000
# row_2   99.990000   0.115913   2.056874  99.990000  99.990000  99.990000
# row_3   99.990000  99.990000   0.910729  99.990000  99.990000   1.164274
# row_4   99.990000  99.990000  99.990000  99.990000  99.990000   0.500909
# ...           ...        ...        ...        ...        ...        ...
# row_95   0.632023  99.990000  99.990000  99.990000   1.342990  99.990000
# row_96  99.990000   0.700762  99.990000   1.221675   0.088607  99.990000
# row_97   1.157206  99.990000   0.557896   0.963973  99.990000   0.271483
# row_98   0.703237  99.990000   1.735655   0.078898  99.990000  99.990000
# row_99  99.990000  99.990000  99.990000   1.517479  99.990000  99.990000
#
#         column_19        sum
# row_0   99.990000  99.990000
# row_1    0.908214   4.018051
# row_2    1.158553   2.344805
# row_3   99.990000   0.337456
# row_4   99.990000   0.124094
# ...           ...        ...
# row_95   0.611289  99.990000
# row_96  99.990000   3.818223
# row_97   0.462247   7.386610
# row_98   0.524606   1.591589
# row_99  99.990000   4.930258
#
# [100 rows x 21 columns]

# %%
# Apply a function on a dataframe column

def circle_area(radius):
    return np.pi * radius ** 2

df['circle_area'] = df['column_1'].apply(circle_area)

# %%
df
# Out:
#         column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# row_0  -0.061867  3.494840  1.366145 -0.282716  1.232646 -0.572733 -0.326738
# row_1  -1.314013  1.432290  1.152912  1.156307  1.297124  0.693444  0.812662
# row_2  -1.452162  1.109068  1.246356  0.716861 -0.803672  1.130528 -0.961859
# row_3   0.767121 -1.410148  0.029519  0.472326  0.020758 -0.489636 -0.527717
# row_4   0.962889  0.765808 -1.365236  1.370107  0.980378  0.609408 -1.289655
# ...          ...       ...       ...       ...       ...       ...       ...
# row_95  1.439471  1.750278  0.884833 -0.679433 -1.032590  1.247483  2.134904
# row_96  1.311461 -0.134759  0.853030  2.352509  2.903976  0.188207  0.390707
# row_97  0.714377  0.043508  3.199866  0.713160 -0.326792 -0.058511 -0.039244
# row_98  0.552253 -0.335895  1.070005  0.103915  0.588325  0.959030  0.253804
# row_99  0.162243  0.091577  1.497532  1.247754  0.409762  0.579131  0.241205
#
#         column_7  column_8  column_9  ...  column_12  column_13  column_14  \
# row_0  -1.213385  0.723445  1.127667  ...  -2.422527  -1.287514  -1.023617
# row_1   2.682947 -0.296179 -0.161810  ...  -0.186374  -0.581903   0.417727
# row_2   1.785122 -0.573043 -0.477888  ...  -0.455231  -1.205265   0.115913
# row_3   0.179453  1.982950  0.561855  ...  -0.854839  -0.490948  -1.151506
# row_4   0.730033  0.089912  0.930447  ...  -0.319074  -1.216257  -1.086353
# ...          ...       ...       ...  ...        ...        ...        ...
# row_95  0.782725 -1.464817 -0.839772  ...   1.867005   0.632023  -2.197502
# row_96 -1.117908 -0.018376  0.763738  ...   0.530554  -0.630892   0.700762
# row_97  2.191589 -0.442348  0.510670  ...  -0.785940   1.157206  -1.140128
# row_98 -0.371038  0.952739  0.032104  ...   0.237859   0.703237  -0.552694
# row_99  1.588943 -0.166546  1.341730  ...   1.308941  -1.505208  -0.550281
#
#         column_15  column_16  column_17  column_18  column_19       sum  \
# row_0   -1.936117   0.284309  -0.275824  -0.292722  -0.291986 -1.078327
# row_1   -0.029335  -1.112440  -1.010581  -0.662007   0.908214  4.018051
# row_2    2.056874  -0.193720  -0.569588  -0.077930   1.158553  2.344805
# row_3    0.910729  -1.401155  -0.326643   1.164274  -0.193142  0.337456
# row_4   -0.149670  -0.791340  -1.361137   0.500909  -1.058117  0.124094
# ...           ...        ...        ...        ...        ...       ...
# row_95  -1.450950  -1.865643   1.342990  -0.685883   0.611289 -0.256764
# row_96  -1.998996   1.221675   0.088607  -0.559924  -1.436727  3.818223
# row_97   0.557896   0.963973  -0.548824   0.271483   0.462247  7.386610
# row_98   1.735655   0.078898  -1.314820  -2.646178   0.524606  1.591589
# row_99  -0.568920   1.517479  -2.393930  -0.780642  -0.747883  4.930258
#
#         circle_area
# row_0     38.371111
# row_1      6.444835
# row_2      3.864261
# row_3      6.247115
# row_4      1.842424
# ...             ...
# row_95     9.624184
# row_96     0.057051
# row_97     0.005947
# row_98     0.354452
# row_99     0.026347
#
# [100 rows x 22 columns]

# %%
# test

value = df.loc['row_1', 'column_1']
circle_area(value)
print("The area of the circle is: ", circle_area(value))
# Out:
# The area of the circle is:  6.444834623023509

# %%
df.loc['row_1', 'circle_area']
# Out:
# 6.444834623023509

# %%
# Pandas multi index

# Create a multi index dataframe - makes it easy to work with multi-dimensional data

# Create a doubly nested dictionary
#import pandas as pd

# Create the nested dictionary

tardis_dict = {
    "person1": {
        "name": "Anirban",
        "code": "tardis",
        "city": "East Lansing",
        "year": 2023,
        "work": "Gamma-rays"
    },
    "person2": {
        "name": "Jing",
        "code": "dalek",
        "city": "East Lansing",
        "year": 2023,
        "work": "Shock waves"
    },
    "person3": {
        "name": "Josh",
        "code": "stardis",
        "city": "East Lansing",
        "year": 2020,
        "work": "positrons"
    },
    "person4": {
        "name": "Andrew",
        "code": "tardis",
        "city": "East Lansing",
        "year": 2020,
        "work": "X-rays"
    },
    "person5": {
        "name": "wolfgang",
        "code": "tardis",
        "city": "New York",
        "year": 2018,
        "work": "Non-LTE"
    }
}

# %%
tardis_dict
# Out:
# {'person1': {'name': 'Anirban',
#   'code': 'tardis',
#   'city': 'East Lansing',
#   'year': 2023,
#   'work': 'Gamma-rays'},
#  'person2': {'name': 'Jing',
#   'code': 'dalek',
#   'city': 'East Lansing',
#   'year': 2023,
#   'work': 'Shock waves'},
#  'person3': {'name': 'Josh',
#   'code': 'stardis',
#   'city': 'East Lansing',
#   'year': 2020,
#   'work': 'positrons'},
#  'person4': {'name': 'Andrew',
#   'code': 'tardis',
#   'city': 'East Lansing',
#   'year': 2020,
#   'work': 'X-rays'},
#  'person5': {'name': 'wolfgang',
#   'code': 'tardis',
#   'city': 'New York',
#   'year': 2018,
#   'work': 'Non-LTE'}}

# %%
# Loop through the outer dictionary
for person, attributes in tardis_dict.items():
    print(f"{person}:")
    
    # Loop through the inner dictionary
    for attribute, value in attributes.items():
        print(f"  {attribute}: {value}")
# Out:
# person1:
#   name: Anirban
#   code: tardis
#   city: East Lansing
#   year: 2023
#   work: Gamma-rays
# person2:
#   name: Jing
#   code: dalek
#   city: East Lansing
#   year: 2023
#   work: Shock waves
# person3:
#   name: Josh
#   code: stardis
#   city: East Lansing
#   year: 2020
#   work: positrons
# person4:
#   name: Andrew
#   code: tardis
#   city: East Lansing
#   year: 2020
#   work: X-rays
# person5:
#   name: wolfgang
#   code: tardis
#   city: New York
#   year: 2018
#   work: Non-LTE

# %%
# Convert the nested dict to a multi-index dataframe

df_tardis = pd.DataFrame.from_dict(tardis_dict, orient='index')

# %% [markdown]
# 1. Efficiently store and manipulate multi-dimensional data
# 2. Readability
# 3. Operations

# %%
df_tardis
# Out:
#              name     code          city  year         work
# person1   Anirban   tardis  East Lansing  2023   Gamma-rays
# person2      Jing    dalek  East Lansing  2023  Shock waves
# person3      Josh  stardis  East Lansing  2020    positrons
# person4    Andrew   tardis  East Lansing  2020       X-rays
# person5  wolfgang   tardis      New York  2018      Non-LTE

# %%
# set the name of the index
df_tardis.index.name = 'person'

# %%
df_tardis
# Out:
#              name     code          city  year         work
# person
# person1   Anirban   tardis  East Lansing  2023   Gamma-rays
# person2      Jing    dalek  East Lansing  2023  Shock waves
# person3      Josh  stardis  East Lansing  2020    positrons
# person4    Andrew   tardis  East Lansing  2020       X-rays
# person5  wolfgang   tardis      New York  2018      Non-LTE

# %%
# create a new random column in the dataframe

np.random.seed(42)

df_tardis['monthly_salary'] = np.random.random(df_tardis.shape[0]) * 5000

# %% [markdown]
# #### Adding complex operations to the dataframe

# %%
df_tardis
# Out:
#              name     code          city  year         work  monthly_salary
# person
# person1   Anirban   tardis  East Lansing  2023   Gamma-rays     1872.700594
# person2      Jing    dalek  East Lansing  2023  Shock waves     4753.571532
# person3      Josh  stardis  East Lansing  2020    positrons     3659.969709
# person4    Andrew   tardis  East Lansing  2020       X-rays     2993.292421
# person5  wolfgang   tardis      New York  2018      Non-LTE      780.093202

# %%
df_tardis = df_tardis.set_index('year', append=True)

# %%
df_tardis
# Out:
#                   name     code          city         work  monthly_salary
# person  year
# person1 2023   Anirban   tardis  East Lansing   Gamma-rays     1872.700594
# person2 2023      Jing    dalek  East Lansing  Shock waves     4753.571532
# person3 2020      Josh  stardis  East Lansing    positrons     3659.969709
# person4 2020    Andrew   tardis  East Lansing       X-rays     2993.292421
# person5 2018  wolfgang   tardis      New York      Non-LTE      780.093202

# %%
# People joined before 2020 should get a hike of 25%
df_tardis.loc[df_tardis.index.get_level_values(1) < 2020, 'monthly_salary'] *= 2.5

# %%
df_tardis
# Out:
#                   name     code          city         work  monthly_salary
# person  year
# person1 2023   Anirban   tardis  East Lansing   Gamma-rays     1872.700594
# person2 2023      Jing    dalek  East Lansing  Shock waves     4753.571532
# person3 2020      Josh  stardis  East Lansing    positrons     3659.969709
# person4 2020    Andrew   tardis  East Lansing       X-rays     2993.292421
# person5 2018  wolfgang   tardis      New York      Non-LTE     1950.233006

# %%
# What is happening above?

# set_index - set the year as the index
# append=True - append the year to the existing index /not replacing the old one "person"
# get_level_values(1) - get the year index
# select the rows where the year is less than 2020
# multiply the monthly salary by 2.5

# %%
x = df_tardis.reset_index().set_index(["city", "year"])

# %%
x
# Out:
#                     person      name     code         work  monthly_salary
# city         year
# East Lansing 2023  person1   Anirban   tardis   Gamma-rays     1872.700594
#              2023  person2      Jing    dalek  Shock waves     4753.571532
#              2020  person3      Josh  stardis    positrons     3659.969709
#              2020  person4    Andrew   tardis       X-rays     2993.292421
# New York     2018  person5  wolfgang   tardis      Non-LTE     1950.233006

# %%
x.loc["East Lansing"]
# Out:
#        person     name     code         work  monthly_salary
# year
# 2023  person1  Anirban   tardis   Gamma-rays     1872.700594
# 2023  person2     Jing    dalek  Shock waves     4753.571532
# 2020  person3     Josh  stardis    positrons     3659.969709
# 2020  person4   Andrew   tardis       X-rays     2993.292421

# %%
x.name
# Out:
# city          year
# East Lansing  2023     Anirban
#               2023        Jing
#               2020        Josh
#               2020      Andrew
# New York      2018    wolfgang
# Name: name, dtype: object
